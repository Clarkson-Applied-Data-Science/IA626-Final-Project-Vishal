# %%
import pymysql

# Define the MySQL connection function
def get_connection():
    return pymysql.connect(
        host="mysql.clarksonmsda.org",
        user="singarv",
        password="Clarkson23@#",
        database="singarv_accident",
        autocommit=True,
        cursorclass=pymysql.cursors.DictCursor
    )

# %%
def create_tables():
    connection = get_connection()
    with connection.cursor() as cursor:
        # Create Accidents table
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS Accidents (
            Accident_Index VARCHAR(50) PRIMARY KEY,
            Longitude DOUBLE,
            Latitude DOUBLE,
            Accident_Severity INT,
            Date DATE,
            Weather_Conditions VARCHAR(255),
            Light_Conditions VARCHAR(255),
            Road_Surface_Conditions VARCHAR(255),
            Number_of_Vehicles INT,
            Number_of_Casualties INT
        );
        """)
        # Create Vehicles table
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS Vehicles (
            Accident_Index VARCHAR(50),
            Vehicle_Reference INT,
            Vehicle_Type VARCHAR(255),
            Vehicle_Manoeuvre VARCHAR(255),
            Skidding_and_Overturning VARCHAR(255),
            FOREIGN KEY (Accident_Index) REFERENCES Accidents(Accident_Index)
        );
        """)
        # Create Casualties table
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS Casualties (
            Accident_Index VARCHAR(50),
            Casualty_Reference INT,
            Casualty_Severity INT,
            Casualty_Class VARCHAR(255),
            Age_of_Casualty INT,
            Sex_of_Casualty VARCHAR(50),
            FOREIGN KEY (Accident_Index) REFERENCES Accidents(Accident_Index)
        );
        """)
    connection.close()
    print("Tables created successfully.")

create_tables()
# Out:
# Tables created successfully.

# %%
import pandas as pd

# Clean column names for MySQL compatibility
def clean_column_names(df):
    df.columns = (
        df.columns
        .str.strip()
        .str.replace(" ", "_")
        .str.replace("-", "_")
        .str.replace("[()]", "", regex=True)
        .str.replace("^\\d+", "col_", regex=True)
    )
    return df

# Filter columns to match the database schema
def filter_columns(df, required_columns):
    return df[required_columns]

# Handle missing values for each table
def handle_missing_values(df, table_name):
    if table_name == 'Accidents':
        df = df.fillna({
            'Longitude': 0.0,
            'Latitude': 0.0,
            'Weather_Conditions': 'Unknown',
            'Light_Conditions': 'Unknown',
            'Road_Surface_Conditions': 'Unknown',
            'Number_of_Vehicles': 0,
            'Number_of_Casualties': 0,
            'Date': '1970-01-01'
        })
    elif table_name == 'Vehicles':
        df = df.fillna({
            'Vehicle_Type': 'Unknown',
            'Vehicle_Manoeuvre': 'Unknown',
            'Skidding_and_Overturning': 'Unknown'
        })
    elif table_name == 'Casualties':
        df = df.fillna({
            'Casualty_Severity': 3,
            'Casualty_Class': 'Unknown',
            'Age_of_Casualty': -1,
            'Sex_of_Casualty': 'Unknown'
        })
    return df

# Load datasets
accidents_df = pd.read_csv('Accidents.csv')
vehicles_df = pd.read_csv('Vehicles.csv')
casualties_df = pd.read_csv('Casualties.csv')

# Clean column names
accidents_df = clean_column_names(accidents_df)
vehicles_df = clean_column_names(vehicles_df)
casualties_df = clean_column_names(casualties_df)

# Convert Date column to YYYY-MM-DD format
if 'Date' in accidents_df.columns:
    accidents_df['Date'] = pd.to_datetime(accidents_df['Date'], format='%d/%m/%Y').dt.strftime('%Y-%m-%d')

# Relevant columns for each table
accident_columns = [
    'Accident_Index', 'Longitude', 'Latitude', 'Accident_Severity', 'Date',
    'Weather_Conditions', 'Light_Conditions', 'Road_Surface_Conditions',
    'Number_of_Vehicles', 'Number_of_Casualties'
]
vehicle_columns = [
    'Accident_Index', 'Vehicle_Reference', 'Vehicle_Type',
    'Vehicle_Manoeuvre', 'Skidding_and_Overturning'
]
casualty_columns = [
    'Accident_Index', 'Casualty_Reference', 'Casualty_Severity',
    'Casualty_Class', 'Age_of_Casualty', 'Sex_of_Casualty'
]

# Filter datasets
accidents_df = filter_columns(accidents_df, accident_columns)
vehicles_df = filter_columns(vehicles_df, vehicle_columns)
casualties_df = filter_columns(casualties_df, casualty_columns)

# Handle missing values
accidents_df = handle_missing_values(accidents_df, 'Accidents')
vehicles_df = handle_missing_values(vehicles_df, 'Vehicles')
casualties_df = handle_missing_values(casualties_df, 'Casualties')
# Out:
# C:\Users\onevs\AppData\Local\Temp\ipykernel_7788\348827966.py:48: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   accidents_df = pd.read_csv('Accidents.csv')

# %%
def insert_data_batch(df, table_name, batch_size=1000):
    connection = get_connection()
    with connection.cursor() as cursor:
        for start in range(0, len(df), batch_size):
            batch = df.iloc[start:start + batch_size]
            cols = ', '.join(batch.columns)  # Extract column names
            vals = ', '.join(['%s'] * len(batch.columns))  # Prepare placeholders
            query = f"INSERT INTO {table_name} ({cols}) VALUES ({vals})"
            data = [tuple(row) for row in batch.to_numpy()]  # Prepare data
            try:
                cursor.executemany(query, data)  # Execute batch insertion
                print(f"Inserted {start + len(batch)} rows into {table_name}")
            except Exception as e:
                print(f"Error inserting batch starting at row {start}: {e}")
    connection.close()

# Insert data into tables
print("Inserting into Accidents table...")
insert_data_batch(accidents_df, 'Accidents')

print("Inserting into Vehicles table...")
insert_data_batch(vehicles_df, 'Vehicles')

print("Inserting into Casualties table...")
insert_data_batch(casualties_df, 'Casualties') 

print("All data inserted successfully!")
# Out:
# Inserting into Vehicles table...
# Inserted 1000 rows into Vehicles
# Inserted 2000 rows into Vehicles
# Inserted 3000 rows into Vehicles
# Inserted 4000 rows into Vehicles
# Inserted 5000 rows into Vehicles
# Inserted 6000 rows into Vehicles
# Inserted 7000 rows into Vehicles
# Inserted 8000 rows into Vehicles
# Inserted 9000 rows into Vehicles
# Inserted 10000 rows into Vehicles
# Inserted 11000 rows into Vehicles
# Inserted 12000 rows into Vehicles
# Inserted 13000 rows into Vehicles
# Inserted 14000 rows into Vehicles
# Inserted 15000 rows into Vehicles
# Inserted 16000 rows into Vehicles
# Inserted 17000 rows into Vehicles
# Inserted 18000 rows into Vehicles
# Inserted 19000 rows into Vehicles
# Inserted 20000 rows into Vehicles
# Inserted 21000 rows into Vehicles
# Inserted 22000 rows into Vehicles
# Inserted 23000 rows into Vehicles
# Inserted 24000 rows into Vehicles
# Inserted 25000 rows into Vehicles
# Inserted 26000 rows into Vehicles
# Inserted 27000 rows into Vehicles
# Inserted 28000 rows into Vehicles
# Inserted 29000 rows into Vehicles
# Inserted 30000 rows into Vehicles
# Inserted 31000 rows into Vehicles
# Inserted 32000 rows into Vehicles
# Inserted 33000 rows into Vehicles
# Inserted 34000 rows into Vehicles
# Inserted 35000 rows into Vehicles
# Inserted 36000 rows into Vehicles
# Inserted 37000 rows into Vehicles
# Inserted 38000 rows into Vehicles
# Inserted 39000 rows into Vehicles
# Inserted 40000 rows into Vehicles
# Inserted 41000 rows into Vehicles
# Inserted 42000 rows into Vehicles
# Inserted 43000 rows into Vehicles
# Inserted 44000 rows into Vehicles
# Inserted 45000 rows into Vehicles
# Inserted 46000 rows into Vehicles
# Inserted 47000 rows into Vehicles
# Inserted 48000 rows into Vehicles
# Inserted 49000 rows into Vehicles
# Inserted 50000 rows into Vehicles
# Inserted 51000 rows into Vehicles
# Inserted 52000 rows into Vehicles
# Inserted 53000 rows into Vehicles
# Inserted 54000 rows into Vehicles
# Inserted 55000 rows into Vehicles
# Inserted 56000 rows into Vehicles
# Inserted 57000 rows into Vehicles
# Inserted 58000 rows into Vehicles
# Inserted 59000 rows into Vehicles
# Inserted 60000 rows into Vehicles
# Inserted 61000 rows into Vehicles
# Inserted 62000 rows into Vehicles
# Inserted 63000 rows into Vehicles
# Inserted 64000 rows into Vehicles
# Inserted 65000 rows into Vehicles
# Inserted 66000 rows into Vehicles
# Inserted 67000 rows into Vehicles
# Inserted 68000 rows into Vehicles
# Inserted 69000 rows into Vehicles
# Inserted 70000 rows into Vehicles
# Inserted 71000 rows into Vehicles
# Inserted 72000 rows into Vehicles
# Inserted 73000 rows into Vehicles
# Inserted 74000 rows into Vehicles
# Inserted 75000 rows into Vehicles
# Inserted 76000 rows into Vehicles
# Inserted 77000 rows into Vehicles
# Inserted 78000 rows into Vehicles
# Inserted 79000 rows into Vehicles
# Inserted 80000 rows into Vehicles
# Inserted 81000 rows into Vehicles
# Inserted 82000 rows into Vehicles
# Inserted 83000 rows into Vehicles
# Inserted 84000 rows into Vehicles
# Inserted 85000 rows into Vehicles
# Inserted 86000 rows into Vehicles
# Inserted 87000 rows into Vehicles
# Inserted 88000 rows into Vehicles
# Inserted 89000 rows into Vehicles
# Inserted 90000 rows into Vehicles
# Inserted 91000 rows into Vehicles
# Inserted 92000 rows into Vehicles
# Inserted 93000 rows into Vehicles
# Inserted 94000 rows into Vehicles
# Inserted 95000 rows into Vehicles
# Inserted 96000 rows into Vehicles
# Inserted 97000 rows into Vehicles
# Inserted 98000 rows into Vehicles
# Inserted 99000 rows into Vehicles
# Inserted 100000 rows into Vehicles
# Inserted 101000 rows into Vehicles
# Inserted 102000 rows into Vehicles
# Inserted 103000 rows into Vehicles
# Inserted 104000 rows into Vehicles
# Inserted 105000 rows into Vehicles
# Inserted 106000 rows into Vehicles
# Inserted 107000 rows into Vehicles
# Inserted 108000 rows into Vehicles
# Inserted 109000 rows into Vehicles
# Inserted 110000 rows into Vehicles
# Inserted 111000 rows into Vehicles
# Inserted 112000 rows into Vehicles
# Inserted 113000 rows into Vehicles
# Inserted 114000 rows into Vehicles
# Inserted 115000 rows into Vehicles
# Inserted 116000 rows into Vehicles
# Inserted 117000 rows into Vehicles
# Inserted 118000 rows into Vehicles
# Inserted 119000 rows into Vehicles
# Inserted 120000 rows into Vehicles
# Inserted 121000 rows into Vehicles
# Inserted 122000 rows into Vehicles
# Inserted 123000 rows into Vehicles
# Inserted 124000 rows into Vehicles
# Inserted 125000 rows into Vehicles
# Inserted 126000 rows into Vehicles
# Inserted 127000 rows into Vehicles
# Inserted 128000 rows into Vehicles
# Inserted 129000 rows into Vehicles
# Inserted 130000 rows into Vehicles
# Inserted 131000 rows into Vehicles
# Inserted 132000 rows into Vehicles
# Inserted 133000 rows into Vehicles
# Inserted 134000 rows into Vehicles
# Inserted 135000 rows into Vehicles
# Inserted 136000 rows into Vehicles
# Inserted 137000 rows into Vehicles
# Inserted 138000 rows into Vehicles
# Inserted 139000 rows into Vehicles
# Inserted 140000 rows into Vehicles
# Inserted 141000 rows into Vehicles
# Inserted 142000 rows into Vehicles
# Inserted 143000 rows into Vehicles
# Inserted 144000 rows into Vehicles
# Inserted 145000 rows into Vehicles
# Inserted 146000 rows into Vehicles
# Inserted 147000 rows into Vehicles
# Inserted 148000 rows into Vehicles
# Inserted 149000 rows into Vehicles
# Inserted 150000 rows into Vehicles
# Inserted 151000 rows into Vehicles
# Inserted 152000 rows into Vehicles
# Inserted 153000 rows into Vehicles
# Inserted 154000 rows into Vehicles
# Inserted 155000 rows into Vehicles
# Inserted 156000 rows into Vehicles
# Inserted 157000 rows into Vehicles
# Inserted 158000 rows into Vehicles
# Inserted 159000 rows into Vehicles
# Inserted 160000 rows into Vehicles
# Inserted 161000 rows into Vehicles
# Inserted 162000 rows into Vehicles
# Inserted 163000 rows into Vehicles
# Inserted 164000 rows into Vehicles
# Inserted 165000 rows into Vehicles
# Inserted 166000 rows into Vehicles
# Inserted 167000 rows into Vehicles
# Inserted 168000 rows into Vehicles
# Inserted 169000 rows into Vehicles
# Inserted 170000 rows into Vehicles
# Inserted 171000 rows into Vehicles
# Inserted 172000 rows into Vehicles
# Inserted 173000 rows into Vehicles
# Inserted 174000 rows into Vehicles
# Inserted 175000 rows into Vehicles
# Inserted 176000 rows into Vehicles
# Inserted 177000 rows into Vehicles
# Inserted 178000 rows into Vehicles
# Inserted 179000 rows into Vehicles
# Inserted 180000 rows into Vehicles
# Inserted 181000 rows into Vehicles
# Inserted 182000 rows into Vehicles
# Inserted 183000 rows into Vehicles
# Inserted 184000 rows into Vehicles
# Inserted 185000 rows into Vehicles
# Inserted 186000 rows into Vehicles
# Inserted 187000 rows into Vehicles
# Inserted 188000 rows into Vehicles
# Inserted 189000 rows into Vehicles
# Inserted 190000 rows into Vehicles
# Inserted 191000 rows into Vehicles
# Inserted 192000 rows into Vehicles
# Inserted 193000 rows into Vehicles
# Inserted 194000 rows into Vehicles
# Inserted 195000 rows into Vehicles
# Inserted 196000 rows into Vehicles
# Inserted 197000 rows into Vehicles
# Inserted 198000 rows into Vehicles
# Inserted 199000 rows into Vehicles
# Inserted 200000 rows into Vehicles
# Inserted 201000 rows into Vehicles
# Inserted 202000 rows into Vehicles
# Inserted 203000 rows into Vehicles
# Inserted 204000 rows into Vehicles
# Inserted 205000 rows into Vehicles
# Inserted 206000 rows into Vehicles
# Inserted 207000 rows into Vehicles
# Inserted 208000 rows into Vehicles
# Inserted 209000 rows into Vehicles
# Inserted 210000 rows into Vehicles
# Inserted 211000 rows into Vehicles
# Inserted 212000 rows into Vehicles
# Inserted 213000 rows into Vehicles
# Inserted 214000 rows into Vehicles
# Inserted 215000 rows into Vehicles
# Inserted 216000 rows into Vehicles
# Inserted 217000 rows into Vehicles
# Inserted 218000 rows into Vehicles
# Inserted 219000 rows into Vehicles
# Inserted 220000 rows into Vehicles
# Inserted 221000 rows into Vehicles
# Inserted 222000 rows into Vehicles
# Inserted 223000 rows into Vehicles
# Inserted 224000 rows into Vehicles
# Inserted 225000 rows into Vehicles
# Inserted 226000 rows into Vehicles
# Inserted 227000 rows into Vehicles
# Inserted 228000 rows into Vehicles
# Inserted 229000 rows into Vehicles
# Inserted 230000 rows into Vehicles
# Inserted 231000 rows into Vehicles
# Inserted 232000 rows into Vehicles
# Inserted 233000 rows into Vehicles
# Inserted 234000 rows into Vehicles
# Inserted 235000 rows into Vehicles
# Inserted 236000 rows into Vehicles
# Inserted 237000 rows into Vehicles
# Inserted 238000 rows into Vehicles
# Inserted 239000 rows into Vehicles
# Inserted 240000 rows into Vehicles
# Inserted 241000 rows into Vehicles
# Inserted 242000 rows into Vehicles
# Inserted 243000 rows into Vehicles
# Inserted 244000 rows into Vehicles
# Inserted 245000 rows into Vehicles
# Inserted 246000 rows into Vehicles
# Inserted 247000 rows into Vehicles
# Inserted 248000 rows into Vehicles
# Inserted 249000 rows into Vehicles
# Inserted 250000 rows into Vehicles
# Inserted 251000 rows into Vehicles
# Inserted 252000 rows into Vehicles
# Inserted 253000 rows into Vehicles
# Inserted 254000 rows into Vehicles
# Inserted 255000 rows into Vehicles
# Inserted 256000 rows into Vehicles
# Inserted 257000 rows into Vehicles
# Inserted 258000 rows into Vehicles
# Inserted 259000 rows into Vehicles
# Inserted 260000 rows into Vehicles
# Inserted 261000 rows into Vehicles
# Inserted 262000 rows into Vehicles
# Inserted 263000 rows into Vehicles
# Inserted 264000 rows into Vehicles
# Inserted 265000 rows into Vehicles
# Inserted 266000 rows into Vehicles
# Inserted 267000 rows into Vehicles
# Inserted 268000 rows into Vehicles
# Inserted 269000 rows into Vehicles
# Inserted 270000 rows into Vehicles
# Inserted 271000 rows into Vehicles
# Inserted 272000 rows into Vehicles
# Inserted 273000 rows into Vehicles
# Inserted 274000 rows into Vehicles
# Inserted 275000 rows into Vehicles
# Inserted 276000 rows into Vehicles
# Inserted 277000 rows into Vehicles
# Inserted 278000 rows into Vehicles
# Inserted 279000 rows into Vehicles
# Inserted 280000 rows into Vehicles
# Inserted 281000 rows into Vehicles
# Inserted 282000 rows into Vehicles
# Inserted 283000 rows into Vehicles
# Inserted 284000 rows into Vehicles
# Inserted 285000 rows into Vehicles
# Inserted 286000 rows into Vehicles
# Inserted 287000 rows into Vehicles
# Inserted 288000 rows into Vehicles
# Inserted 289000 rows into Vehicles
# Inserted 290000 rows into Vehicles
# Inserted 291000 rows into Vehicles
# Inserted 292000 rows into Vehicles
# Inserted 293000 rows into Vehicles
# Inserted 294000 rows into Vehicles
# Inserted 295000 rows into Vehicles
# Inserted 296000 rows into Vehicles
# Inserted 297000 rows into Vehicles
# Inserted 298000 rows into Vehicles
# Inserted 299000 rows into Vehicles
# Inserted 300000 rows into Vehicles
# Inserted 301000 rows into Vehicles
# Inserted 302000 rows into Vehicles
# Inserted 303000 rows into Vehicles
# Inserted 304000 rows into Vehicles
# Inserted 305000 rows into Vehicles
# Inserted 306000 rows into Vehicles
# Inserted 307000 rows into Vehicles
# Inserted 308000 rows into Vehicles
# Inserted 309000 rows into Vehicles
# Inserted 310000 rows into Vehicles
# Inserted 311000 rows into Vehicles
# Inserted 312000 rows into Vehicles
# Inserted 313000 rows into Vehicles
# Inserted 314000 rows into Vehicles
# Inserted 315000 rows into Vehicles
# Inserted 316000 rows into Vehicles
# Inserted 317000 rows into Vehicles
# Inserted 318000 rows into Vehicles
# Inserted 319000 rows into Vehicles
# Inserted 320000 rows into Vehicles
# Inserted 321000 rows into Vehicles
# Inserted 322000 rows into Vehicles
# Inserted 323000 rows into Vehicles
# Inserted 324000 rows into Vehicles
# Inserted 325000 rows into Vehicles
# Inserted 326000 rows into Vehicles
# Inserted 327000 rows into Vehicles
# Inserted 328000 rows into Vehicles
# Inserted 329000 rows into Vehicles
# Inserted 330000 rows into Vehicles
# Inserted 331000 rows into Vehicles
# Inserted 332000 rows into Vehicles
# Inserted 333000 rows into Vehicles
# Inserted 334000 rows into Vehicles
# Inserted 335000 rows into Vehicles
# Inserted 336000 rows into Vehicles
# Inserted 337000 rows into Vehicles
# Inserted 338000 rows into Vehicles
# Inserted 339000 rows into Vehicles
# Inserted 340000 rows into Vehicles
# Inserted 341000 rows into Vehicles
# Inserted 342000 rows into Vehicles
# Inserted 343000 rows into Vehicles
# Inserted 344000 rows into Vehicles
# Inserted 345000 rows into Vehicles
# Inserted 346000 rows into Vehicles
# Inserted 347000 rows into Vehicles
# Inserted 348000 rows into Vehicles
# Inserted 349000 rows into Vehicles
# Inserted 350000 rows into Vehicles
# Inserted 351000 rows into Vehicles
# Inserted 352000 rows into Vehicles
# Inserted 353000 rows into Vehicles
# Inserted 354000 rows into Vehicles
# Inserted 355000 rows into Vehicles
# Inserted 356000 rows into Vehicles
# Inserted 357000 rows into Vehicles
# Inserted 358000 rows into Vehicles
# Inserted 359000 rows into Vehicles
# Inserted 360000 rows into Vehicles
# Inserted 361000 rows into Vehicles
# Inserted 362000 rows into Vehicles
# Inserted 363000 rows into Vehicles
# Inserted 364000 rows into Vehicles
# Inserted 365000 rows into Vehicles
# Inserted 366000 rows into Vehicles
# Inserted 367000 rows into Vehicles
# Inserted 368000 rows into Vehicles
# Inserted 369000 rows into Vehicles
# Inserted 370000 rows into Vehicles
# Inserted 371000 rows into Vehicles
# Inserted 372000 rows into Vehicles
# Inserted 373000 rows into Vehicles
# Inserted 374000 rows into Vehicles
# Inserted 375000 rows into Vehicles
# Inserted 376000 rows into Vehicles
# Inserted 377000 rows into Vehicles
# Inserted 378000 rows into Vehicles
# Inserted 379000 rows into Vehicles
# Inserted 380000 rows into Vehicles
# Inserted 381000 rows into Vehicles
# Inserted 382000 rows into Vehicles
# Inserted 383000 rows into Vehicles
# Inserted 384000 rows into Vehicles
# Inserted 385000 rows into Vehicles
# Inserted 386000 rows into Vehicles
# Inserted 387000 rows into Vehicles
# Inserted 388000 rows into Vehicles
# Inserted 389000 rows into Vehicles
# Inserted 390000 rows into Vehicles
# Inserted 391000 rows into Vehicles
# Inserted 392000 rows into Vehicles
# Inserted 393000 rows into Vehicles
# Inserted 394000 rows into Vehicles
# Inserted 395000 rows into Vehicles
# Inserted 396000 rows into Vehicles
# Inserted 397000 rows into Vehicles
# Inserted 398000 rows into Vehicles
# Inserted 399000 rows into Vehicles
# Inserted 400000 rows into Vehicles
# Inserted 401000 rows into Vehicles
# Inserted 402000 rows into Vehicles
# Inserted 403000 rows into Vehicles
# Inserted 404000 rows into Vehicles
# Inserted 405000 rows into Vehicles
# Inserted 406000 rows into Vehicles
# Inserted 407000 rows into Vehicles
# Inserted 408000 rows into Vehicles
# Inserted 409000 rows into Vehicles
# Inserted 410000 rows into Vehicles
# Inserted 411000 rows into Vehicles
# Inserted 412000 rows into Vehicles
# Inserted 413000 rows into Vehicles
# Inserted 414000 rows into Vehicles
# Inserted 415000 rows into Vehicles
# Inserted 416000 rows into Vehicles
# Inserted 417000 rows into Vehicles
# Inserted 418000 rows into Vehicles
# Inserted 419000 rows into Vehicles
# Inserted 420000 rows into Vehicles
# Inserted 421000 rows into Vehicles
# Inserted 422000 rows into Vehicles
# Inserted 423000 rows into Vehicles
# Inserted 424000 rows into Vehicles
# Inserted 425000 rows into Vehicles
# Inserted 426000 rows into Vehicles
# Inserted 427000 rows into Vehicles
# Inserted 428000 rows into Vehicles
# Inserted 429000 rows into Vehicles
# Inserted 430000 rows into Vehicles
# Inserted 431000 rows into Vehicles
# Inserted 432000 rows into Vehicles
# Inserted 433000 rows into Vehicles
# Inserted 434000 rows into Vehicles
# Inserted 435000 rows into Vehicles
# Inserted 436000 rows into Vehicles
# Inserted 437000 rows into Vehicles
# Inserted 438000 rows into Vehicles
# Inserted 439000 rows into Vehicles
# Inserted 440000 rows into Vehicles
# Inserted 441000 rows into Vehicles
# Inserted 442000 rows into Vehicles
# Inserted 443000 rows into Vehicles
# Inserted 444000 rows into Vehicles
# Inserted 445000 rows into Vehicles
# Inserted 446000 rows into Vehicles
# Inserted 447000 rows into Vehicles
# Inserted 448000 rows into Vehicles
# Inserted 449000 rows into Vehicles
# Inserted 450000 rows into Vehicles
# Inserted 451000 rows into Vehicles
# Inserted 452000 rows into Vehicles
# Inserted 453000 rows into Vehicles
# Inserted 454000 rows into Vehicles
# Inserted 455000 rows into Vehicles
# Inserted 456000 rows into Vehicles
# Inserted 457000 rows into Vehicles
# Inserted 458000 rows into Vehicles
# Inserted 459000 rows into Vehicles
# Inserted 460000 rows into Vehicles
# Inserted 461000 rows into Vehicles
# Inserted 462000 rows into Vehicles
# Inserted 463000 rows into Vehicles
# Inserted 464000 rows into Vehicles
# Inserted 465000 rows into Vehicles
# Inserted 466000 rows into Vehicles
# Inserted 467000 rows into Vehicles
# Inserted 468000 rows into Vehicles
# Inserted 469000 rows into Vehicles
# Inserted 470000 rows into Vehicles
# Inserted 471000 rows into Vehicles
# Inserted 472000 rows into Vehicles
# Inserted 473000 rows into Vehicles
# Inserted 474000 rows into Vehicles
# Inserted 475000 rows into Vehicles
# Inserted 476000 rows into Vehicles
# Inserted 477000 rows into Vehicles
# Inserted 478000 rows into Vehicles
# Inserted 479000 rows into Vehicles
# Inserted 480000 rows into Vehicles
# Inserted 481000 rows into Vehicles
# Inserted 482000 rows into Vehicles
# Inserted 483000 rows into Vehicles
# Inserted 484000 rows into Vehicles
# Inserted 485000 rows into Vehicles
# Inserted 486000 rows into Vehicles
# Inserted 487000 rows into Vehicles
# Inserted 488000 rows into Vehicles
# Inserted 489000 rows into Vehicles
# Inserted 490000 rows into Vehicles
# Inserted 491000 rows into Vehicles
# Inserted 492000 rows into Vehicles
# Inserted 493000 rows into Vehicles
# Inserted 494000 rows into Vehicles
# Inserted 495000 rows into Vehicles
# Inserted 496000 rows into Vehicles
# Inserted 497000 rows into Vehicles
# Inserted 498000 rows into Vehicles
# Inserted 499000 rows into Vehicles
# Inserted 500000 rows into Vehicles
# Inserted 501000 rows into Vehicles
# Inserted 502000 rows into Vehicles
# Inserted 503000 rows into Vehicles
# Inserted 504000 rows into Vehicles
# Inserted 505000 rows into Vehicles
# Inserted 506000 rows into Vehicles
# Inserted 507000 rows into Vehicles
# Inserted 508000 rows into Vehicles
# Inserted 509000 rows into Vehicles
# Inserted 510000 rows into Vehicles
# Inserted 511000 rows into Vehicles
# Inserted 512000 rows into Vehicles
# Inserted 513000 rows into Vehicles
# Inserted 514000 rows into Vehicles
# Inserted 515000 rows into Vehicles
# Inserted 516000 rows into Vehicles
# Inserted 517000 rows into Vehicles
# Inserted 518000 rows into Vehicles
# Inserted 519000 rows into Vehicles
# Inserted 520000 rows into Vehicles
# Inserted 521000 rows into Vehicles
# Inserted 522000 rows into Vehicles
# Inserted 523000 rows into Vehicles
# Inserted 524000 rows into Vehicles
# Inserted 525000 rows into Vehicles
# Inserted 526000 rows into Vehicles
# Inserted 527000 rows into Vehicles
# Inserted 528000 rows into Vehicles
# Inserted 529000 rows into Vehicles
# Inserted 530000 rows into Vehicles
# Inserted 531000 rows into Vehicles
# Inserted 532000 rows into Vehicles
# Inserted 533000 rows into Vehicles
# Inserted 534000 rows into Vehicles
# Inserted 535000 rows into Vehicles
# Inserted 536000 rows into Vehicles
# Inserted 537000 rows into Vehicles
# Inserted 538000 rows into Vehicles
# Inserted 539000 rows into Vehicles
# Inserted 540000 rows into Vehicles
# Inserted 541000 rows into Vehicles
# Inserted 542000 rows into Vehicles
# Inserted 543000 rows into Vehicles
# Inserted 544000 rows into Vehicles
# Inserted 545000 rows into Vehicles
# Inserted 546000 rows into Vehicles
# Inserted 547000 rows into Vehicles
# Inserted 548000 rows into Vehicles
# Inserted 549000 rows into Vehicles
# Inserted 550000 rows into Vehicles
# Inserted 551000 rows into Vehicles
# Inserted 552000 rows into Vehicles
# Inserted 553000 rows into Vehicles
# Inserted 554000 rows into Vehicles
# Inserted 555000 rows into Vehicles
# Inserted 556000 rows into Vehicles
# Inserted 557000 rows into Vehicles
# Inserted 558000 rows into Vehicles
# Inserted 559000 rows into Vehicles
# Inserted 560000 rows into Vehicles
# Inserted 561000 rows into Vehicles
# Inserted 562000 rows into Vehicles
# Inserted 563000 rows into Vehicles
# Inserted 564000 rows into Vehicles
# Inserted 565000 rows into Vehicles
# Inserted 566000 rows into Vehicles
# Inserted 567000 rows into Vehicles
# Inserted 568000 rows into Vehicles
# Inserted 569000 rows into Vehicles
# Inserted 570000 rows into Vehicles
# Inserted 571000 rows into Vehicles
# Inserted 572000 rows into Vehicles
# Inserted 573000 rows into Vehicles
# Inserted 574000 rows into Vehicles
# Inserted 575000 rows into Vehicles
# Inserted 576000 rows into Vehicles
# Inserted 577000 rows into Vehicles
# Inserted 578000 rows into Vehicles
# Inserted 579000 rows into Vehicles
# Inserted 580000 rows into Vehicles
# Inserted 581000 rows into Vehicles
# Inserted 582000 rows into Vehicles
# Inserted 583000 rows into Vehicles
# Inserted 584000 rows into Vehicles
# Inserted 585000 rows into Vehicles
# Inserted 586000 rows into Vehicles
# Inserted 587000 rows into Vehicles
# Inserted 588000 rows into Vehicles
# Inserted 589000 rows into Vehicles
# Inserted 590000 rows into Vehicles
# Inserted 591000 rows into Vehicles
# Inserted 592000 rows into Vehicles
# Inserted 593000 rows into Vehicles
# Inserted 594000 rows into Vehicles
# Inserted 595000 rows into Vehicles
# Inserted 596000 rows into Vehicles
# Inserted 597000 rows into Vehicles
# Inserted 598000 rows into Vehicles
# Inserted 599000 rows into Vehicles
# Inserted 600000 rows into Vehicles
# Inserted 601000 rows into Vehicles
# Inserted 602000 rows into Vehicles
# Inserted 603000 rows into Vehicles
# Inserted 604000 rows into Vehicles
# Inserted 605000 rows into Vehicles
# Inserted 606000 rows into Vehicles
# Inserted 607000 rows into Vehicles
# Inserted 608000 rows into Vehicles
# Inserted 609000 rows into Vehicles
# Inserted 610000 rows into Vehicles
# Inserted 611000 rows into Vehicles
# Inserted 612000 rows into Vehicles
# Inserted 613000 rows into Vehicles
# Inserted 614000 rows into Vehicles
# Inserted 615000 rows into Vehicles
# Inserted 616000 rows into Vehicles
# Inserted 617000 rows into Vehicles
# Inserted 618000 rows into Vehicles
# Inserted 619000 rows into Vehicles
# Inserted 620000 rows into Vehicles
# Inserted 621000 rows into Vehicles
# Inserted 622000 rows into Vehicles
# Inserted 623000 rows into Vehicles
# Inserted 624000 rows into Vehicles
# Inserted 625000 rows into Vehicles
# Inserted 626000 rows into Vehicles
# Inserted 627000 rows into Vehicles
# Inserted 628000 rows into Vehicles
# Inserted 629000 rows into Vehicles
# Inserted 630000 rows into Vehicles
# Inserted 631000 rows into Vehicles
# Inserted 632000 rows into Vehicles
# Inserted 633000 rows into Vehicles
# Inserted 634000 rows into Vehicles
# Inserted 635000 rows into Vehicles
# Inserted 636000 rows into Vehicles
# Inserted 637000 rows into Vehicles
# Inserted 638000 rows into Vehicles
# Inserted 639000 rows into Vehicles
# Inserted 640000 rows into Vehicles
# Inserted 641000 rows into Vehicles
# Inserted 642000 rows into Vehicles
# Inserted 643000 rows into Vehicles
# Inserted 644000 rows into Vehicles
# Inserted 645000 rows into Vehicles
# Inserted 646000 rows into Vehicles
# Inserted 647000 rows into Vehicles
# Inserted 648000 rows into Vehicles
# Inserted 649000 rows into Vehicles
# Inserted 650000 rows into Vehicles
# Inserted 651000 rows into Vehicles
# Inserted 652000 rows into Vehicles
# Inserted 653000 rows into Vehicles
# Inserted 654000 rows into Vehicles
# Inserted 655000 rows into Vehicles
# Inserted 656000 rows into Vehicles
# Inserted 657000 rows into Vehicles
# Inserted 658000 rows into Vehicles
# Inserted 659000 rows into Vehicles
# Inserted 660000 rows into Vehicles
# Inserted 661000 rows into Vehicles
# Inserted 662000 rows into Vehicles
# Inserted 663000 rows into Vehicles
# Inserted 664000 rows into Vehicles
# Inserted 665000 rows into Vehicles
# Inserted 666000 rows into Vehicles
# Inserted 667000 rows into Vehicles
# Inserted 668000 rows into Vehicles
# Inserted 669000 rows into Vehicles
# Inserted 670000 rows into Vehicles
# Inserted 671000 rows into Vehicles
# Inserted 672000 rows into Vehicles
# Inserted 673000 rows into Vehicles
# Inserted 674000 rows into Vehicles
# Inserted 675000 rows into Vehicles
# Inserted 676000 rows into Vehicles
# Inserted 677000 rows into Vehicles
# Inserted 678000 rows into Vehicles
# Inserted 679000 rows into Vehicles
# Inserted 680000 rows into Vehicles
# Inserted 681000 rows into Vehicles
# Inserted 682000 rows into Vehicles
# Inserted 683000 rows into Vehicles
# Inserted 684000 rows into Vehicles
# Inserted 685000 rows into Vehicles
# Inserted 686000 rows into Vehicles
# Inserted 687000 rows into Vehicles
# Inserted 688000 rows into Vehicles
# Inserted 689000 rows into Vehicles
# Inserted 690000 rows into Vehicles
# Inserted 691000 rows into Vehicles
# Inserted 692000 rows into Vehicles
# Inserted 693000 rows into Vehicles
# Inserted 694000 rows into Vehicles
# Inserted 695000 rows into Vehicles
# Inserted 696000 rows into Vehicles
# Inserted 697000 rows into Vehicles
# Inserted 698000 rows into Vehicles
# Inserted 699000 rows into Vehicles
# Inserted 700000 rows into Vehicles
# Inserted 701000 rows into Vehicles
# Inserted 702000 rows into Vehicles
# Inserted 703000 rows into Vehicles
# Inserted 704000 rows into Vehicles
# Inserted 705000 rows into Vehicles
# Inserted 706000 rows into Vehicles
# Inserted 707000 rows into Vehicles
# Inserted 708000 rows into Vehicles
# Inserted 709000 rows into Vehicles
# Inserted 710000 rows into Vehicles
# Inserted 711000 rows into Vehicles
# Inserted 712000 rows into Vehicles
# Inserted 713000 rows into Vehicles
# Inserted 714000 rows into Vehicles
# Inserted 715000 rows into Vehicles
# Inserted 716000 rows into Vehicles
# Inserted 717000 rows into Vehicles
# Inserted 718000 rows into Vehicles
# Inserted 719000 rows into Vehicles
# Inserted 720000 rows into Vehicles
# Inserted 721000 rows into Vehicles
# Inserted 722000 rows into Vehicles
# Inserted 723000 rows into Vehicles
# Inserted 724000 rows into Vehicles
# Inserted 725000 rows into Vehicles
# Inserted 726000 rows into Vehicles
# Inserted 727000 rows into Vehicles
# Inserted 728000 rows into Vehicles
# Inserted 729000 rows into Vehicles
# Inserted 730000 rows into Vehicles
# Inserted 731000 rows into Vehicles
# Inserted 732000 rows into Vehicles
# Inserted 733000 rows into Vehicles
# Inserted 734000 rows into Vehicles
# Inserted 735000 rows into Vehicles
# Inserted 736000 rows into Vehicles
# Inserted 737000 rows into Vehicles
# Inserted 738000 rows into Vehicles
# Inserted 739000 rows into Vehicles
# Inserted 740000 rows into Vehicles
# Inserted 741000 rows into Vehicles
# Inserted 742000 rows into Vehicles
# Inserted 743000 rows into Vehicles
# Inserted 744000 rows into Vehicles
# Inserted 745000 rows into Vehicles
# Inserted 746000 rows into Vehicles
# Inserted 747000 rows into Vehicles
# Inserted 748000 rows into Vehicles
# Inserted 749000 rows into Vehicles
# Inserted 750000 rows into Vehicles
# Inserted 751000 rows into Vehicles
# Inserted 752000 rows into Vehicles
# Inserted 753000 rows into Vehicles
# Inserted 754000 rows into Vehicles
# Inserted 755000 rows into Vehicles
# Inserted 756000 rows into Vehicles
# Inserted 757000 rows into Vehicles
# Inserted 758000 rows into Vehicles
# Inserted 759000 rows into Vehicles
# Inserted 760000 rows into Vehicles
# Inserted 761000 rows into Vehicles
# Inserted 762000 rows into Vehicles
# Inserted 763000 rows into Vehicles
# Inserted 764000 rows into Vehicles
# Inserted 765000 rows into Vehicles
# Inserted 766000 rows into Vehicles
# Inserted 767000 rows into Vehicles
# Inserted 768000 rows into Vehicles
# Inserted 769000 rows into Vehicles
# Inserted 770000 rows into Vehicles
# Inserted 771000 rows into Vehicles
# Inserted 772000 rows into Vehicles
# Inserted 773000 rows into Vehicles
# Inserted 774000 rows into Vehicles
# Inserted 775000 rows into Vehicles
# Inserted 776000 rows into Vehicles
# Inserted 777000 rows into Vehicles
# Inserted 778000 rows into Vehicles
# Inserted 779000 rows into Vehicles
# Inserted 780000 rows into Vehicles
# Inserted 781000 rows into Vehicles
# Inserted 782000 rows into Vehicles
# Inserted 783000 rows into Vehicles
# Inserted 784000 rows into Vehicles
# Inserted 785000 rows into Vehicles
# Inserted 786000 rows into Vehicles
# Inserted 787000 rows into Vehicles
# Inserted 788000 rows into Vehicles
# Inserted 789000 rows into Vehicles
# Inserted 790000 rows into Vehicles
# Inserted 791000 rows into Vehicles
# Inserted 792000 rows into Vehicles
# Inserted 793000 rows into Vehicles
# Inserted 794000 rows into Vehicles
# Inserted 795000 rows into Vehicles
# Inserted 796000 rows into Vehicles
# Inserted 797000 rows into Vehicles
# Inserted 798000 rows into Vehicles
# Inserted 799000 rows into Vehicles
# Inserted 800000 rows into Vehicles
# Inserted 801000 rows into Vehicles
# Inserted 802000 rows into Vehicles
# Inserted 803000 rows into Vehicles
# Inserted 804000 rows into Vehicles
# Inserted 805000 rows into Vehicles
# Inserted 806000 rows into Vehicles
# Inserted 807000 rows into Vehicles
# Inserted 808000 rows into Vehicles
# Inserted 809000 rows into Vehicles
# Inserted 810000 rows into Vehicles
# Inserted 811000 rows into Vehicles
# Inserted 812000 rows into Vehicles
# Inserted 813000 rows into Vehicles
# Inserted 814000 rows into Vehicles
# Inserted 815000 rows into Vehicles
# Inserted 816000 rows into Vehicles
# Inserted 817000 rows into Vehicles
# Inserted 818000 rows into Vehicles
# Inserted 819000 rows into Vehicles
# Inserted 820000 rows into Vehicles
# Inserted 821000 rows into Vehicles
# Inserted 822000 rows into Vehicles
# Inserted 823000 rows into Vehicles
# Inserted 824000 rows into Vehicles
# Inserted 825000 rows into Vehicles
# Inserted 826000 rows into Vehicles
# Inserted 827000 rows into Vehicles
# Inserted 828000 rows into Vehicles
# Inserted 829000 rows into Vehicles
# Inserted 830000 rows into Vehicles
# Inserted 831000 rows into Vehicles
# Inserted 832000 rows into Vehicles
# Inserted 833000 rows into Vehicles
# Inserted 834000 rows into Vehicles
# Inserted 835000 rows into Vehicles
# Inserted 836000 rows into Vehicles
# Inserted 837000 rows into Vehicles
# Inserted 838000 rows into Vehicles
# Inserted 839000 rows into Vehicles
# Inserted 840000 rows into Vehicles
# Inserted 841000 rows into Vehicles
# Inserted 842000 rows into Vehicles
# Inserted 843000 rows into Vehicles
# Inserted 844000 rows into Vehicles
# Inserted 845000 rows into Vehicles
# Inserted 846000 rows into Vehicles
# Inserted 847000 rows into Vehicles
# Inserted 848000 rows into Vehicles
# Inserted 849000 rows into Vehicles
# Inserted 850000 rows into Vehicles
# Inserted 851000 rows into Vehicles
# Inserted 852000 rows into Vehicles
# Inserted 853000 rows into Vehicles
# Inserted 854000 rows into Vehicles
# Inserted 855000 rows into Vehicles
# Inserted 856000 rows into Vehicles
# Inserted 857000 rows into Vehicles
# Inserted 858000 rows into Vehicles
# Inserted 859000 rows into Vehicles
# Inserted 860000 rows into Vehicles
# Inserted 861000 rows into Vehicles
# Inserted 862000 rows into Vehicles
# Inserted 863000 rows into Vehicles
# Inserted 864000 rows into Vehicles
# Inserted 865000 rows into Vehicles
# Inserted 866000 rows into Vehicles
# Inserted 867000 rows into Vehicles
# Inserted 868000 rows into Vehicles
# Inserted 869000 rows into Vehicles
# Inserted 870000 rows into Vehicles
# Inserted 871000 rows into Vehicles
# Inserted 872000 rows into Vehicles
# Inserted 873000 rows into Vehicles
# Inserted 874000 rows into Vehicles
# Inserted 875000 rows into Vehicles
# Inserted 876000 rows into Vehicles
# Inserted 877000 rows into Vehicles
# Inserted 878000 rows into Vehicles
# Inserted 879000 rows into Vehicles
# Inserted 880000 rows into Vehicles
# Inserted 881000 rows into Vehicles
# Inserted 882000 rows into Vehicles
# Inserted 883000 rows into Vehicles
# Inserted 884000 rows into Vehicles
# Inserted 885000 rows into Vehicles
# Inserted 886000 rows into Vehicles
# Inserted 887000 rows into Vehicles
# Inserted 888000 rows into Vehicles
# Inserted 889000 rows into Vehicles
# Inserted 890000 rows into Vehicles
# Inserted 891000 rows into Vehicles
# Inserted 892000 rows into Vehicles
# Inserted 893000 rows into Vehicles
# Inserted 894000 rows into Vehicles
# Inserted 895000 rows into Vehicles
# Inserted 896000 rows into Vehicles
# Inserted 897000 rows into Vehicles
# Inserted 898000 rows into Vehicles
# Inserted 899000 rows into Vehicles
# Inserted 900000 rows into Vehicles
# Inserted 901000 rows into Vehicles
# Inserted 902000 rows into Vehicles
# Inserted 903000 rows into Vehicles
# Inserted 904000 rows into Vehicles
# Inserted 905000 rows into Vehicles
# Inserted 906000 rows into Vehicles
# Inserted 907000 rows into Vehicles
# Inserted 908000 rows into Vehicles
# Inserted 909000 rows into Vehicles
# Inserted 910000 rows into Vehicles
# Inserted 911000 rows into Vehicles
# Inserted 912000 rows into Vehicles
# Inserted 913000 rows into Vehicles
# Inserted 914000 rows into Vehicles
# Inserted 915000 rows into Vehicles
# Inserted 916000 rows into Vehicles
# Inserted 917000 rows into Vehicles
# Inserted 918000 rows into Vehicles
# Inserted 919000 rows into Vehicles
# Inserted 920000 rows into Vehicles
# Inserted 921000 rows into Vehicles
# Inserted 922000 rows into Vehicles
# Inserted 923000 rows into Vehicles
# Inserted 924000 rows into Vehicles
# Inserted 925000 rows into Vehicles
# Inserted 926000 rows into Vehicles
# Inserted 927000 rows into Vehicles
# Inserted 928000 rows into Vehicles
# Inserted 929000 rows into Vehicles
# Inserted 930000 rows into Vehicles
# Inserted 931000 rows into Vehicles
# Inserted 932000 rows into Vehicles
# Inserted 933000 rows into Vehicles
# Inserted 934000 rows into Vehicles
# Inserted 935000 rows into Vehicles
# Inserted 936000 rows into Vehicles
# Inserted 937000 rows into Vehicles
# Inserted 938000 rows into Vehicles
# Inserted 939000 rows into Vehicles
# Inserted 940000 rows into Vehicles
# Inserted 941000 rows into Vehicles
# Inserted 942000 rows into Vehicles
# Inserted 943000 rows into Vehicles
# Inserted 944000 rows into Vehicles
# Inserted 945000 rows into Vehicles
# Inserted 946000 rows into Vehicles
# Inserted 947000 rows into Vehicles
# Inserted 948000 rows into Vehicles
# Inserted 949000 rows into Vehicles
# Inserted 950000 rows into Vehicles
# Inserted 951000 rows into Vehicles
# Inserted 952000 rows into Vehicles
# Inserted 953000 rows into Vehicles
# Inserted 954000 rows into Vehicles
# Inserted 955000 rows into Vehicles
# Inserted 956000 rows into Vehicles
# Inserted 957000 rows into Vehicles
# Inserted 958000 rows into Vehicles
# Inserted 959000 rows into Vehicles
# Inserted 960000 rows into Vehicles
# Inserted 961000 rows into Vehicles
# Inserted 962000 rows into Vehicles
# Inserted 963000 rows into Vehicles
# Inserted 964000 rows into Vehicles
# Inserted 965000 rows into Vehicles
# Inserted 966000 rows into Vehicles
# Inserted 967000 rows into Vehicles
# Inserted 968000 rows into Vehicles
# Inserted 969000 rows into Vehicles
# Inserted 970000 rows into Vehicles
# Inserted 971000 rows into Vehicles
# Inserted 972000 rows into Vehicles
# Inserted 973000 rows into Vehicles
# Inserted 974000 rows into Vehicles
# Inserted 975000 rows into Vehicles
# Inserted 976000 rows into Vehicles
# Inserted 977000 rows into Vehicles
# Inserted 978000 rows into Vehicles
# Inserted 979000 rows into Vehicles
# Inserted 980000 rows into Vehicles
# Inserted 981000 rows into Vehicles
# Inserted 982000 rows into Vehicles
# Inserted 983000 rows into Vehicles
# Inserted 984000 rows into Vehicles
# Inserted 985000 rows into Vehicles
# Inserted 986000 rows into Vehicles
# Inserted 987000 rows into Vehicles
# Inserted 988000 rows into Vehicles
# Inserted 989000 rows into Vehicles
# Inserted 990000 rows into Vehicles
# Inserted 991000 rows into Vehicles
# Inserted 992000 rows into Vehicles
# Inserted 993000 rows into Vehicles
# Inserted 994000 rows into Vehicles
# Inserted 995000 rows into Vehicles
# Inserted 996000 rows into Vehicles
# Inserted 997000 rows into Vehicles
# Inserted 998000 rows into Vehicles
# Inserted 999000 rows into Vehicles
# Inserted 1000000 rows into Vehicles
# Inserted 1001000 rows into Vehicles
# Inserted 1002000 rows into Vehicles
# Inserted 1003000 rows into Vehicles
# Inserted 1004000 rows into Vehicles
# Inserted 1005000 rows into Vehicles
# Inserted 1006000 rows into Vehicles
# Inserted 1007000 rows into Vehicles
# Inserted 1008000 rows into Vehicles
# Inserted 1009000 rows into Vehicles
# Inserted 1010000 rows into Vehicles
# Inserted 1011000 rows into Vehicles
# Inserted 1012000 rows into Vehicles
# Inserted 1013000 rows into Vehicles
# Inserted 1014000 rows into Vehicles
# Inserted 1015000 rows into Vehicles
# Inserted 1016000 rows into Vehicles
# Inserted 1017000 rows into Vehicles
# Inserted 1018000 rows into Vehicles
# Inserted 1019000 rows into Vehicles
# Inserted 1020000 rows into Vehicles
# Inserted 1021000 rows into Vehicles
# Inserted 1022000 rows into Vehicles
# Inserted 1023000 rows into Vehicles
# Inserted 1024000 rows into Vehicles
# Inserted 1025000 rows into Vehicles
# Inserted 1026000 rows into Vehicles
# Inserted 1027000 rows into Vehicles
# Inserted 1028000 rows into Vehicles
# Inserted 1029000 rows into Vehicles
# Inserted 1030000 rows into Vehicles
# Inserted 1031000 rows into Vehicles
# Inserted 1032000 rows into Vehicles
# Inserted 1033000 rows into Vehicles
# Inserted 1034000 rows into Vehicles
# Inserted 1035000 rows into Vehicles
# Inserted 1036000 rows into Vehicles
# Inserted 1037000 rows into Vehicles
# Inserted 1038000 rows into Vehicles
# Inserted 1039000 rows into Vehicles
# Inserted 1040000 rows into Vehicles
# Inserted 1041000 rows into Vehicles
# Inserted 1042000 rows into Vehicles
# Inserted 1043000 rows into Vehicles
# Inserted 1044000 rows into Vehicles
# Inserted 1045000 rows into Vehicles
# Inserted 1046000 rows into Vehicles
# Inserted 1047000 rows into Vehicles
# Inserted 1048000 rows into Vehicles
# Inserted 1049000 rows into Vehicles
# Inserted 1050000 rows into Vehicles
# Inserted 1051000 rows into Vehicles
# Inserted 1052000 rows into Vehicles
# Inserted 1053000 rows into Vehicles
# Inserted 1054000 rows into Vehicles
# Inserted 1055000 rows into Vehicles
# Inserted 1056000 rows into Vehicles
# Inserted 1057000 rows into Vehicles
# Inserted 1058000 rows into Vehicles
# Inserted 1059000 rows into Vehicles
# Inserted 1060000 rows into Vehicles
# Inserted 1061000 rows into Vehicles
# Inserted 1062000 rows into Vehicles
# Inserted 1063000 rows into Vehicles
# Inserted 1064000 rows into Vehicles
# Inserted 1065000 rows into Vehicles
# Inserted 1066000 rows into Vehicles
# Inserted 1067000 rows into Vehicles
# Inserted 1068000 rows into Vehicles
# Inserted 1069000 rows into Vehicles
# Inserted 1070000 rows into Vehicles
# Inserted 1071000 rows into Vehicles
# Inserted 1072000 rows into Vehicles
# Inserted 1073000 rows into Vehicles
# Inserted 1074000 rows into Vehicles
# Inserted 1075000 rows into Vehicles
# Inserted 1076000 rows into Vehicles
# Inserted 1077000 rows into Vehicles
# Inserted 1078000 rows into Vehicles
# Inserted 1079000 rows into Vehicles
# Inserted 1080000 rows into Vehicles
# Inserted 1081000 rows into Vehicles
# Inserted 1082000 rows into Vehicles
# Inserted 1083000 rows into Vehicles
# Inserted 1084000 rows into Vehicles
# Inserted 1085000 rows into Vehicles
# Inserted 1086000 rows into Vehicles
# Inserted 1087000 rows into Vehicles
# Inserted 1088000 rows into Vehicles
# Inserted 1089000 rows into Vehicles
# Inserted 1090000 rows into Vehicles
# Inserted 1091000 rows into Vehicles
# Inserted 1092000 rows into Vehicles
# Inserted 1093000 rows into Vehicles
# Inserted 1094000 rows into Vehicles
# Inserted 1095000 rows into Vehicles
# Inserted 1096000 rows into Vehicles
# Inserted 1097000 rows into Vehicles
# Inserted 1098000 rows into Vehicles
# Inserted 1099000 rows into Vehicles
# Inserted 1100000 rows into Vehicles
# Inserted 1101000 rows into Vehicles
# Inserted 1102000 rows into Vehicles
# Inserted 1103000 rows into Vehicles
# Inserted 1104000 rows into Vehicles
# Inserted 1105000 rows into Vehicles
# Inserted 1106000 rows into Vehicles
# Inserted 1107000 rows into Vehicles
# Inserted 1108000 rows into Vehicles
# Inserted 1109000 rows into Vehicles
# Inserted 1110000 rows into Vehicles
# Inserted 1111000 rows into Vehicles
# Inserted 1112000 rows into Vehicles
# Inserted 1113000 rows into Vehicles
# Inserted 1114000 rows into Vehicles
# Inserted 1115000 rows into Vehicles
# Inserted 1116000 rows into Vehicles
# Inserted 1117000 rows into Vehicles
# Inserted 1118000 rows into Vehicles
# Inserted 1119000 rows into Vehicles
# Inserted 1120000 rows into Vehicles
# Inserted 1121000 rows into Vehicles
# Inserted 1122000 rows into Vehicles
# Inserted 1123000 rows into Vehicles
# Inserted 1124000 rows into Vehicles
# Inserted 1125000 rows into Vehicles
# Inserted 1126000 rows into Vehicles
# Inserted 1127000 rows into Vehicles
# Inserted 1128000 rows into Vehicles
# Inserted 1129000 rows into Vehicles
# Inserted 1130000 rows into Vehicles
# Inserted 1131000 rows into Vehicles
# Inserted 1132000 rows into Vehicles
# Inserted 1133000 rows into Vehicles
# Inserted 1134000 rows into Vehicles
# Inserted 1135000 rows into Vehicles
# Inserted 1136000 rows into Vehicles
# Inserted 1137000 rows into Vehicles
# Inserted 1138000 rows into Vehicles
# Inserted 1139000 rows into Vehicles
# Inserted 1140000 rows into Vehicles
# Inserted 1141000 rows into Vehicles
# Inserted 1142000 rows into Vehicles
# Inserted 1143000 rows into Vehicles
# Inserted 1144000 rows into Vehicles
# Inserted 1145000 rows into Vehicles
# Inserted 1146000 rows into Vehicles
# Inserted 1147000 rows into Vehicles
# Inserted 1148000 rows into Vehicles
# Inserted 1149000 rows into Vehicles
# Inserted 1150000 rows into Vehicles
# Inserted 1151000 rows into Vehicles
# Inserted 1152000 rows into Vehicles
# Inserted 1153000 rows into Vehicles
# Inserted 1154000 rows into Vehicles
# Inserted 1155000 rows into Vehicles
# Inserted 1156000 rows into Vehicles
# Inserted 1157000 rows into Vehicles
# Inserted 1158000 rows into Vehicles
# Inserted 1159000 rows into Vehicles
# Inserted 1160000 rows into Vehicles
# Inserted 1161000 rows into Vehicles
# Inserted 1162000 rows into Vehicles
# Inserted 1163000 rows into Vehicles
# Inserted 1164000 rows into Vehicles
# Inserted 1165000 rows into Vehicles
# Inserted 1166000 rows into Vehicles
# Inserted 1167000 rows into Vehicles
# Inserted 1168000 rows into Vehicles
# Inserted 1169000 rows into Vehicles
# Inserted 1170000 rows into Vehicles
# Inserted 1171000 rows into Vehicles
# Inserted 1172000 rows into Vehicles
# Inserted 1173000 rows into Vehicles
# Inserted 1174000 rows into Vehicles
# Inserted 1175000 rows into Vehicles
# Inserted 1176000 rows into Vehicles
# Inserted 1177000 rows into Vehicles
# Inserted 1178000 rows into Vehicles
# Inserted 1179000 rows into Vehicles
# Inserted 1180000 rows into Vehicles
# Inserted 1181000 rows into Vehicles
# Inserted 1182000 rows into Vehicles
# Inserted 1183000 rows into Vehicles
# Inserted 1184000 rows into Vehicles
# Inserted 1185000 rows into Vehicles
# Inserted 1186000 rows into Vehicles
# Inserted 1187000 rows into Vehicles
# Inserted 1188000 rows into Vehicles
# Inserted 1189000 rows into Vehicles
# Inserted 1190000 rows into Vehicles
# Inserted 1191000 rows into Vehicles
# Inserted 1192000 rows into Vehicles
# Inserted 1193000 rows into Vehicles
# Inserted 1194000 rows into Vehicles
# Inserted 1195000 rows into Vehicles
# Inserted 1196000 rows into Vehicles
# Inserted 1197000 rows into Vehicles
# Inserted 1198000 rows into Vehicles
# Inserted 1199000 rows into Vehicles
# Inserted 1200000 rows into Vehicles
# Inserted 1201000 rows into Vehicles
# Inserted 1202000 rows into Vehicles
# Inserted 1203000 rows into Vehicles
# Inserted 1204000 rows into Vehicles
# Inserted 1205000 rows into Vehicles
# Inserted 1206000 rows into Vehicles
# Inserted 1207000 rows into Vehicles
# Inserted 1208000 rows into Vehicles
# Inserted 1209000 rows into Vehicles
# Inserted 1210000 rows into Vehicles
# Inserted 1211000 rows into Vehicles
# Inserted 1212000 rows into Vehicles
# Inserted 1213000 rows into Vehicles
# Inserted 1214000 rows into Vehicles
# Inserted 1215000 rows into Vehicles
# Inserted 1216000 rows into Vehicles
# Inserted 1217000 rows into Vehicles
# Inserted 1218000 rows into Vehicles
# Inserted 1219000 rows into Vehicles
# Inserted 1220000 rows into Vehicles
# Inserted 1221000 rows into Vehicles
# Inserted 1222000 rows into Vehicles
# Inserted 1223000 rows into Vehicles
# Inserted 1224000 rows into Vehicles
# Inserted 1225000 rows into Vehicles
# Inserted 1226000 rows into Vehicles
# Inserted 1227000 rows into Vehicles
# Inserted 1228000 rows into Vehicles
# Inserted 1229000 rows into Vehicles
# Inserted 1230000 rows into Vehicles
# Inserted 1231000 rows into Vehicles
# Inserted 1232000 rows into Vehicles
# Inserted 1233000 rows into Vehicles
# Inserted 1234000 rows into Vehicles
# Inserted 1235000 rows into Vehicles
# Inserted 1236000 rows into Vehicles
# Inserted 1237000 rows into Vehicles
# Inserted 1238000 rows into Vehicles
# Inserted 1239000 rows into Vehicles
# Inserted 1240000 rows into Vehicles
# Inserted 1241000 rows into Vehicles
# Inserted 1242000 rows into Vehicles
# Inserted 1243000 rows into Vehicles
# Inserted 1244000 rows into Vehicles
# Inserted 1245000 rows into Vehicles
# Inserted 1246000 rows into Vehicles
# Inserted 1247000 rows into Vehicles
# Inserted 1248000 rows into Vehicles
# Inserted 1249000 rows into Vehicles
# Inserted 1250000 rows into Vehicles
# Inserted 1251000 rows into Vehicles
# Inserted 1252000 rows into Vehicles
# Inserted 1253000 rows into Vehicles
# Inserted 1254000 rows into Vehicles
# Inserted 1255000 rows into Vehicles
# Inserted 1256000 rows into Vehicles
# Inserted 1257000 rows into Vehicles
# Inserted 1258000 rows into Vehicles
# Inserted 1259000 rows into Vehicles
# Inserted 1260000 rows into Vehicles
# Inserted 1261000 rows into Vehicles
# Inserted 1262000 rows into Vehicles
# Inserted 1263000 rows into Vehicles
# Inserted 1264000 rows into Vehicles
# Inserted 1265000 rows into Vehicles
# Inserted 1266000 rows into Vehicles
# Inserted 1267000 rows into Vehicles
# Inserted 1268000 rows into Vehicles
# Inserted 1269000 rows into Vehicles
# Inserted 1270000 rows into Vehicles
# Inserted 1271000 rows into Vehicles
# Inserted 1272000 rows into Vehicles
# Inserted 1273000 rows into Vehicles
# Inserted 1274000 rows into Vehicles
# Inserted 1275000 rows into Vehicles
# Inserted 1276000 rows into Vehicles
# Inserted 1277000 rows into Vehicles
# Inserted 1278000 rows into Vehicles
# Inserted 1279000 rows into Vehicles
# Inserted 1280000 rows into Vehicles
# Inserted 1281000 rows into Vehicles
# Inserted 1282000 rows into Vehicles
# Inserted 1283000 rows into Vehicles
# Inserted 1284000 rows into Vehicles
# Inserted 1285000 rows into Vehicles
# Inserted 1286000 rows into Vehicles
# Inserted 1287000 rows into Vehicles
# Inserted 1288000 rows into Vehicles
# Inserted 1289000 rows into Vehicles
# Inserted 1290000 rows into Vehicles
# Inserted 1291000 rows into Vehicles
# Inserted 1292000 rows into Vehicles
# Inserted 1293000 rows into Vehicles
# Inserted 1294000 rows into Vehicles
# Inserted 1295000 rows into Vehicles
# Inserted 1296000 rows into Vehicles
# Inserted 1297000 rows into Vehicles
# Inserted 1298000 rows into Vehicles
# Inserted 1299000 rows into Vehicles
# Inserted 1300000 rows into Vehicles
# Inserted 1301000 rows into Vehicles
# Inserted 1302000 rows into Vehicles
# Inserted 1303000 rows into Vehicles
# Inserted 1304000 rows into Vehicles
# Inserted 1305000 rows into Vehicles
# Inserted 1306000 rows into Vehicles
# Inserted 1307000 rows into Vehicles
# Inserted 1308000 rows into Vehicles
# Inserted 1309000 rows into Vehicles
# Inserted 1310000 rows into Vehicles
# Inserted 1311000 rows into Vehicles
# Inserted 1312000 rows into Vehicles
# Inserted 1313000 rows into Vehicles
# Inserted 1314000 rows into Vehicles
# Inserted 1315000 rows into Vehicles
# Inserted 1316000 rows into Vehicles
# Inserted 1317000 rows into Vehicles
# Inserted 1318000 rows into Vehicles
# Inserted 1319000 rows into Vehicles
# Inserted 1320000 rows into Vehicles
# Inserted 1321000 rows into Vehicles
# Inserted 1322000 rows into Vehicles
# Inserted 1323000 rows into Vehicles
# Inserted 1324000 rows into Vehicles
# Inserted 1325000 rows into Vehicles
# Inserted 1326000 rows into Vehicles
# Inserted 1327000 rows into Vehicles
# Inserted 1328000 rows into Vehicles
# Inserted 1329000 rows into Vehicles
# Inserted 1330000 rows into Vehicles
# Inserted 1331000 rows into Vehicles
# Inserted 1332000 rows into Vehicles
# Inserted 1333000 rows into Vehicles
# Inserted 1334000 rows into Vehicles
# Inserted 1335000 rows into Vehicles
# Inserted 1336000 rows into Vehicles
# Inserted 1337000 rows into Vehicles
# Inserted 1338000 rows into Vehicles
# Inserted 1339000 rows into Vehicles
# Inserted 1340000 rows into Vehicles
# Inserted 1341000 rows into Vehicles
# Inserted 1342000 rows into Vehicles
# Inserted 1343000 rows into Vehicles
# Inserted 1344000 rows into Vehicles
# Inserted 1345000 rows into Vehicles
# Inserted 1346000 rows into Vehicles
# Inserted 1347000 rows into Vehicles
# Inserted 1348000 rows into Vehicles
# Inserted 1349000 rows into Vehicles
# Inserted 1350000 rows into Vehicles
# Inserted 1351000 rows into Vehicles
# Inserted 1352000 rows into Vehicles
# Inserted 1353000 rows into Vehicles
# Inserted 1354000 rows into Vehicles
# Inserted 1355000 rows into Vehicles
# Inserted 1356000 rows into Vehicles
# Inserted 1357000 rows into Vehicles
# Inserted 1358000 rows into Vehicles
# Inserted 1359000 rows into Vehicles
# Inserted 1360000 rows into Vehicles
# Inserted 1361000 rows into Vehicles
# Inserted 1362000 rows into Vehicles
# Inserted 1363000 rows into Vehicles
# ...
# Inserted 1798000 rows into Casualties
# Inserted 1799000 rows into Casualties
# Inserted 1800000 rows into Casualties
# Inserted 1801000 rows into Casualties
# Inserted 1802000 rows into Casualties
# Inserted 1803000 rows into Casualties
# Inserted 1804000 rows into Casualties
# Inserted 1805000 rows into Casualties
# Inserted 1806000 rows into Casualties
# Inserted 1807000 rows into Casualties
# Inserted 1808000 rows into Casualties
# Inserted 1809000 rows into Casualties
# Inserted 1810000 rows into Casualties
# Inserted 1811000 rows into Casualties
# Inserted 1812000 rows into Casualties
# Inserted 1813000 rows into Casualties
# Inserted 1814000 rows into Casualties
# Inserted 1815000 rows into Casualties
# Inserted 1816000 rows into Casualties
# Inserted 1817000 rows into Casualties
# Inserted 1818000 rows into Casualties
# Inserted 1819000 rows into Casualties
# Inserted 1820000 rows into Casualties
# Inserted 1821000 rows into Casualties
# Inserted 1822000 rows into Casualties
# Inserted 1823000 rows into Casualties
# Inserted 1824000 rows into Casualties
# Inserted 1825000 rows into Casualties
# Inserted 1826000 rows into Casualties
# Inserted 1827000 rows into Casualties
# Inserted 1828000 rows into Casualties
# Inserted 1829000 rows into Casualties
# Inserted 1830000 rows into Casualties
# Inserted 1831000 rows into Casualties
# Inserted 1832000 rows into Casualties
# Inserted 1833000 rows into Casualties
# Inserted 1834000 rows into Casualties
# Inserted 1835000 rows into Casualties
# Inserted 1836000 rows into Casualties
# Inserted 1837000 rows into Casualties
# Inserted 1838000 rows into Casualties
# Inserted 1839000 rows into Casualties
# Inserted 1840000 rows into Casualties
# Inserted 1841000 rows into Casualties
# Inserted 1842000 rows into Casualties
# Inserted 1843000 rows into Casualties
# Inserted 1844000 rows into Casualties
# Inserted 1845000 rows into Casualties
# Inserted 1846000 rows into Casualties
# Inserted 1847000 rows into Casualties
# Inserted 1848000 rows into Casualties
# Inserted 1849000 rows into Casualties
# Inserted 1850000 rows into Casualties
# Inserted 1851000 rows into Casualties
# Inserted 1852000 rows into Casualties
# Inserted 1853000 rows into Casualties
# Inserted 1854000 rows into Casualties
# Inserted 1855000 rows into Casualties
# Inserted 1856000 rows into Casualties
# Inserted 1857000 rows into Casualties
# Inserted 1858000 rows into Casualties
# Inserted 1859000 rows into Casualties
# Inserted 1860000 rows into Casualties
# Inserted 1861000 rows into Casualties
# Inserted 1862000 rows into Casualties
# Inserted 1863000 rows into Casualties
# Inserted 1864000 rows into Casualties
# Inserted 1865000 rows into Casualties
# Inserted 1866000 rows into Casualties
# Inserted 1867000 rows into Casualties
# Inserted 1868000 rows into Casualties
# Inserted 1869000 rows into Casualties
# Inserted 1870000 rows into Casualties
# Inserted 1871000 rows into Casualties
# Inserted 1872000 rows into Casualties
# Inserted 1873000 rows into Casualties
# Inserted 1874000 rows into Casualties
# Inserted 1875000 rows into Casualties
# Inserted 1876000 rows into Casualties
# Inserted 1877000 rows into Casualties
# Inserted 1878000 rows into Casualties
# Inserted 1879000 rows into Casualties
# Inserted 1880000 rows into Casualties
# Inserted 1881000 rows into Casualties
# Inserted 1882000 rows into Casualties
# Inserted 1883000 rows into Casualties
# Inserted 1884000 rows into Casualties
# Inserted 1885000 rows into Casualties
# Inserted 1886000 rows into Casualties
# Inserted 1887000 rows into Casualties
# Inserted 1888000 rows into Casualties
# Inserted 1889000 rows into Casualties
# Inserted 1890000 rows into Casualties
# Inserted 1891000 rows into Casualties
# Inserted 1892000 rows into Casualties
# Inserted 1893000 rows into Casualties
# Inserted 1894000 rows into Casualties
# Inserted 1895000 rows into Casualties
# Inserted 1896000 rows into Casualties
# Inserted 1897000 rows into Casualties
# Inserted 1898000 rows into Casualties
# Inserted 1899000 rows into Casualties
# Inserted 1900000 rows into Casualties
# Inserted 1901000 rows into Casualties
# Inserted 1902000 rows into Casualties
# Inserted 1903000 rows into Casualties
# Inserted 1904000 rows into Casualties
# Inserted 1905000 rows into Casualties
# Inserted 1906000 rows into Casualties
# Inserted 1907000 rows into Casualties
# Inserted 1908000 rows into Casualties
# Inserted 1909000 rows into Casualties
# Inserted 1910000 rows into Casualties
# Inserted 1911000 rows into Casualties
# Inserted 1912000 rows into Casualties
# Inserted 1913000 rows into Casualties
# Inserted 1914000 rows into Casualties
# Inserted 1915000 rows into Casualties
# Inserted 1916000 rows into Casualties
# Inserted 1917000 rows into Casualties
# Inserted 1918000 rows into Casualties
# Inserted 1919000 rows into Casualties
# Inserted 1920000 rows into Casualties
# Inserted 1921000 rows into Casualties
# Inserted 1922000 rows into Casualties
# Inserted 1923000 rows into Casualties
# Inserted 1924000 rows into Casualties
# Inserted 1925000 rows into Casualties
# Inserted 1926000 rows into Casualties
# Inserted 1927000 rows into Casualties
# Inserted 1928000 rows into Casualties
# Inserted 1929000 rows into Casualties
# Inserted 1930000 rows into Casualties
# Inserted 1931000 rows into Casualties
# Inserted 1932000 rows into Casualties
# Inserted 1933000 rows into Casualties
# Inserted 1934000 rows into Casualties
# Inserted 1935000 rows into Casualties
# Inserted 1936000 rows into Casualties
# Inserted 1937000 rows into Casualties
# Inserted 1938000 rows into Casualties
# Inserted 1939000 rows into Casualties
# Inserted 1940000 rows into Casualties
# Inserted 1941000 rows into Casualties
# Inserted 1942000 rows into Casualties
# Inserted 1943000 rows into Casualties
# Inserted 1944000 rows into Casualties
# Inserted 1945000 rows into Casualties
# Inserted 1946000 rows into Casualties
# Inserted 1947000 rows into Casualties
# Inserted 1948000 rows into Casualties
# Inserted 1949000 rows into Casualties
# Inserted 1950000 rows into Casualties
# Inserted 1951000 rows into Casualties
# Inserted 1952000 rows into Casualties
# Inserted 1953000 rows into Casualties
# Inserted 1954000 rows into Casualties
# Inserted 1955000 rows into Casualties
# Inserted 1956000 rows into Casualties
# Inserted 1957000 rows into Casualties
# Inserted 1958000 rows into Casualties
# Inserted 1959000 rows into Casualties
# Inserted 1960000 rows into Casualties
# Inserted 1961000 rows into Casualties
# Inserted 1962000 rows into Casualties
# Inserted 1963000 rows into Casualties
# Inserted 1964000 rows into Casualties
# Inserted 1965000 rows into Casualties
# Inserted 1966000 rows into Casualties
# Inserted 1967000 rows into Casualties
# Inserted 1968000 rows into Casualties
# Inserted 1969000 rows into Casualties
# Inserted 1970000 rows into Casualties
# Inserted 1971000 rows into Casualties
# Inserted 1972000 rows into Casualties
# Inserted 1973000 rows into Casualties
# Inserted 1974000 rows into Casualties
# Inserted 1975000 rows into Casualties
# Inserted 1976000 rows into Casualties
# Inserted 1977000 rows into Casualties
# Inserted 1978000 rows into Casualties
# Inserted 1979000 rows into Casualties
# Inserted 1980000 rows into Casualties
# Inserted 1981000 rows into Casualties
# Inserted 1982000 rows into Casualties
# Inserted 1983000 rows into Casualties
# Inserted 1984000 rows into Casualties
# Inserted 1985000 rows into Casualties
# Inserted 1986000 rows into Casualties
# Inserted 1987000 rows into Casualties
# Inserted 1988000 rows into Casualties
# Inserted 1989000 rows into Casualties
# Inserted 1990000 rows into Casualties
# Inserted 1991000 rows into Casualties
# Inserted 1992000 rows into Casualties
# Inserted 1993000 rows into Casualties
# Inserted 1994000 rows into Casualties
# Inserted 1995000 rows into Casualties
# Inserted 1996000 rows into Casualties
# Inserted 1997000 rows into Casualties
# Inserted 1998000 rows into Casualties
# Inserted 1999000 rows into Casualties
# Inserted 2000000 rows into Casualties
# Inserted 2001000 rows into Casualties
# Inserted 2002000 rows into Casualties
# Inserted 2003000 rows into Casualties
# Inserted 2004000 rows into Casualties
# Inserted 2005000 rows into Casualties
# Inserted 2006000 rows into Casualties
# Inserted 2007000 rows into Casualties
# Inserted 2008000 rows into Casualties
# Inserted 2009000 rows into Casualties
# Inserted 2010000 rows into Casualties
# Inserted 2011000 rows into Casualties
# Inserted 2012000 rows into Casualties
# Inserted 2013000 rows into Casualties
# Inserted 2014000 rows into Casualties
# Inserted 2015000 rows into Casualties
# Inserted 2016000 rows into Casualties
# Inserted 2017000 rows into Casualties
# Inserted 2018000 rows into Casualties
# Inserted 2019000 rows into Casualties
# Inserted 2020000 rows into Casualties
# Inserted 2021000 rows into Casualties
# Inserted 2022000 rows into Casualties
# Inserted 2023000 rows into Casualties
# Inserted 2024000 rows into Casualties
# Inserted 2025000 rows into Casualties
# Inserted 2026000 rows into Casualties
# Inserted 2027000 rows into Casualties
# Inserted 2028000 rows into Casualties
# Inserted 2029000 rows into Casualties
# Inserted 2030000 rows into Casualties
# Inserted 2031000 rows into Casualties
# Inserted 2032000 rows into Casualties
# Inserted 2033000 rows into Casualties
# Inserted 2034000 rows into Casualties
# Inserted 2035000 rows into Casualties
# Inserted 2036000 rows into Casualties
# Inserted 2037000 rows into Casualties
# Inserted 2038000 rows into Casualties
# Inserted 2039000 rows into Casualties
# Inserted 2040000 rows into Casualties
# Inserted 2041000 rows into Casualties
# Inserted 2042000 rows into Casualties
# Inserted 2043000 rows into Casualties
# Inserted 2044000 rows into Casualties
# Inserted 2045000 rows into Casualties
# Inserted 2046000 rows into Casualties
# Inserted 2047000 rows into Casualties
# Inserted 2048000 rows into Casualties
# Inserted 2049000 rows into Casualties
# Inserted 2050000 rows into Casualties
# Inserted 2051000 rows into Casualties
# Inserted 2052000 rows into Casualties
# Inserted 2053000 rows into Casualties
# Inserted 2054000 rows into Casualties
# Inserted 2055000 rows into Casualties
# Inserted 2056000 rows into Casualties
# Inserted 2057000 rows into Casualties
# Inserted 2058000 rows into Casualties
# Inserted 2059000 rows into Casualties
# Inserted 2060000 rows into Casualties
# Inserted 2061000 rows into Casualties
# Inserted 2062000 rows into Casualties
# Inserted 2063000 rows into Casualties
# Inserted 2064000 rows into Casualties
# Inserted 2065000 rows into Casualties
# Inserted 2066000 rows into Casualties
# Inserted 2067000 rows into Casualties
# Inserted 2068000 rows into Casualties
# Inserted 2069000 rows into Casualties
# Inserted 2070000 rows into Casualties
# Inserted 2071000 rows into Casualties
# Inserted 2072000 rows into Casualties
# Inserted 2073000 rows into Casualties
# Inserted 2074000 rows into Casualties
# Inserted 2075000 rows into Casualties
# Inserted 2076000 rows into Casualties
# Inserted 2077000 rows into Casualties
# Inserted 2078000 rows into Casualties
# Inserted 2079000 rows into Casualties
# Inserted 2080000 rows into Casualties
# Inserted 2081000 rows into Casualties
# Inserted 2082000 rows into Casualties
# Inserted 2083000 rows into Casualties
# Inserted 2084000 rows into Casualties
# Inserted 2085000 rows into Casualties
# Inserted 2086000 rows into Casualties
# Inserted 2087000 rows into Casualties
# Inserted 2088000 rows into Casualties
# Inserted 2089000 rows into Casualties
# Inserted 2090000 rows into Casualties
# Inserted 2091000 rows into Casualties
# Inserted 2092000 rows into Casualties
# Inserted 2093000 rows into Casualties
# Inserted 2094000 rows into Casualties
# Inserted 2095000 rows into Casualties
# Inserted 2096000 rows into Casualties
# Inserted 2097000 rows into Casualties
# Inserted 2098000 rows into Casualties
# Inserted 2099000 rows into Casualties
# Inserted 2100000 rows into Casualties
# Inserted 2101000 rows into Casualties
# Inserted 2102000 rows into Casualties
# Inserted 2103000 rows into Casualties
# Inserted 2104000 rows into Casualties
# Inserted 2105000 rows into Casualties
# Inserted 2106000 rows into Casualties
# Inserted 2107000 rows into Casualties
# Inserted 2108000 rows into Casualties
# Inserted 2109000 rows into Casualties
# Inserted 2110000 rows into Casualties
# Inserted 2111000 rows into Casualties
# Inserted 2112000 rows into Casualties
# Inserted 2113000 rows into Casualties
# Inserted 2114000 rows into Casualties
# Inserted 2115000 rows into Casualties
# Inserted 2116000 rows into Casualties
# Inserted 2117000 rows into Casualties
# Inserted 2118000 rows into Casualties
# Inserted 2119000 rows into Casualties
# Inserted 2120000 rows into Casualties
# Inserted 2121000 rows into Casualties
# Inserted 2122000 rows into Casualties
# Inserted 2123000 rows into Casualties
# Inserted 2124000 rows into Casualties
# Inserted 2125000 rows into Casualties
# Inserted 2126000 rows into Casualties
# Inserted 2127000 rows into Casualties
# Inserted 2128000 rows into Casualties
# Inserted 2129000 rows into Casualties
# Inserted 2130000 rows into Casualties
# Inserted 2131000 rows into Casualties
# Inserted 2132000 rows into Casualties
# Inserted 2133000 rows into Casualties
# Inserted 2134000 rows into Casualties
# Inserted 2135000 rows into Casualties
# Inserted 2136000 rows into Casualties
# Inserted 2137000 rows into Casualties
# Inserted 2138000 rows into Casualties
# Inserted 2139000 rows into Casualties
# Inserted 2140000 rows into Casualties
# Inserted 2141000 rows into Casualties
# Inserted 2142000 rows into Casualties
# Inserted 2143000 rows into Casualties
# Inserted 2144000 rows into Casualties
# Inserted 2145000 rows into Casualties
# Inserted 2146000 rows into Casualties
# Inserted 2147000 rows into Casualties
# Inserted 2148000 rows into Casualties
# Inserted 2149000 rows into Casualties
# Inserted 2150000 rows into Casualties
# Inserted 2151000 rows into Casualties
# Inserted 2152000 rows into Casualties
# Inserted 2153000 rows into Casualties
# Inserted 2154000 rows into Casualties
# Inserted 2155000 rows into Casualties
# Inserted 2156000 rows into Casualties
# Inserted 2157000 rows into Casualties
# Inserted 2158000 rows into Casualties
# Inserted 2159000 rows into Casualties
# Inserted 2160000 rows into Casualties
# Inserted 2161000 rows into Casualties
# Inserted 2162000 rows into Casualties
# Inserted 2163000 rows into Casualties
# Inserted 2164000 rows into Casualties
# Inserted 2165000 rows into Casualties
# Inserted 2166000 rows into Casualties
# Inserted 2167000 rows into Casualties
# Inserted 2168000 rows into Casualties
# Inserted 2169000 rows into Casualties
# Inserted 2170000 rows into Casualties
# Inserted 2171000 rows into Casualties
# Inserted 2172000 rows into Casualties
# Inserted 2173000 rows into Casualties
# Inserted 2174000 rows into Casualties
# Inserted 2175000 rows into Casualties
# Inserted 2176000 rows into Casualties
# Inserted 2177000 rows into Casualties
# Inserted 2178000 rows into Casualties
# Inserted 2179000 rows into Casualties
# Inserted 2180000 rows into Casualties
# Inserted 2181000 rows into Casualties
# Inserted 2182000 rows into Casualties
# Inserted 2183000 rows into Casualties
# Inserted 2184000 rows into Casualties
# Inserted 2185000 rows into Casualties
# Inserted 2186000 rows into Casualties
# Inserted 2187000 rows into Casualties
# Inserted 2188000 rows into Casualties
# Inserted 2189000 rows into Casualties
# Inserted 2190000 rows into Casualties
# Inserted 2191000 rows into Casualties
# Inserted 2192000 rows into Casualties
# Inserted 2193000 rows into Casualties
# Inserted 2194000 rows into Casualties
# Inserted 2195000 rows into Casualties
# Inserted 2196000 rows into Casualties
# Inserted 2197000 rows into Casualties
# Inserted 2198000 rows into Casualties
# Inserted 2199000 rows into Casualties
# Inserted 2200000 rows into Casualties
# Inserted 2201000 rows into Casualties
# Inserted 2202000 rows into Casualties
# Inserted 2203000 rows into Casualties
# Inserted 2204000 rows into Casualties
# Inserted 2205000 rows into Casualties
# Inserted 2206000 rows into Casualties
# Inserted 2207000 rows into Casualties
# Inserted 2208000 rows into Casualties
# Inserted 2209000 rows into Casualties
# Inserted 2210000 rows into Casualties
# Inserted 2211000 rows into Casualties
# Inserted 2212000 rows into Casualties
# Inserted 2213000 rows into Casualties
# Inserted 2214000 rows into Casualties
# Inserted 2215000 rows into Casualties
# Inserted 2216000 rows into Casualties
# Inserted 2216720 rows into Casualties
# All data inserted successfully!
